# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeeth938/ML_Day5/blob/main/ML_Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/Car.csv")

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data.head()
# Out:
#          Price  Mileage   Make    Model  ... Doors Cruise  Sound  Leather
# 0  17314.10313     8221  Buick  Century  ...     4      1      1        1
# 1  17542.03608     9135  Buick  Century  ...     4      1      1        0
# 2  16218.84786    13196  Buick  Century  ...     4      1      1        0
# 3  16336.91314    16342  Buick  Century  ...     4      1      0        0
# 4  16339.17032    19832  Buick  Century  ...     4      1      0        1
#
# [5 rows x 12 columns]

# %%
data.tail()
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [5 rows x 12 columns]

# %%
data.shape
# Out:
# (804, 12)

# %%
data.describe()
# Out:
#               Price       Mileage  ...       Sound     Leather
# count    804.000000    804.000000  ...  804.000000  804.000000
# mean   21343.143767  19831.934080  ...    0.679104    0.723881
# std     9884.852801   8196.319707  ...    0.467111    0.447355
# min     8638.930895    266.000000  ...    0.000000    0.000000
# 25%    14273.073875  14623.500000  ...    0.000000    0.000000
# 50%    18024.995020  20913.500000  ...    1.000000    1.000000
# 75%    26717.316635  25213.000000  ...    1.000000    1.000000
# max    70755.466720  50387.000000  ...    1.000000    1.000000
#
# [8 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804 entries, 0 to 803
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     804 non-null    float64
#  1   Mileage   804 non-null    int64
#  2   Make      804 non-null    object
#  3   Model     804 non-null    object
#  4   Trim      804 non-null    object
#  5   Type      804 non-null    object
#  6   Cylinder  804 non-null    int64
#  7   Liter     804 non-null    float64
#  8   Doors     804 non-null    int64
#  9   Cruise    804 non-null    int64
#  10  Sound     804 non-null    int64
#  11  Leather   804 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 75.5+ KB

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# Price       0
# Mileage     0
# Make        0
# Model       0
# Trim        0
# Type        0
# Cylinder    0
# Liter       0
# Doors       0
# Cruise      0
# Sound       0
# Leather     0
# dtype: int64

# %%
#creating a heat map

sns.heatmap(data.isnull())

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
sns.distplot(data["Price"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(y=data["Price"])

# %%
sns.displot(data["Mileage"])

# %%
# creating a scatter plot for mileage in x-axis and price in y-axis
plt.figure(figsize=(10,5))
sns.scatterplot(x="Mileage",y="Price",data=data)

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="Mileage",y="Price",data=data,hue="Cylinder")

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
data["Make"].value_counts()
# Out:
# Chevrolet    320
# Pontiac      150
# SAAB         114
# Cadillac      80
# Buick         80
# Saturn        60
# Name: Make, dtype: int64

# %%
sns.countplot(data["Make"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data["Model"].unique()
# Out:
# array(['Century', 'Lacrosse', 'Lesabre', 'Park Avenue', 'CST-V', 'CTS',
#        'Deville', 'STS-V6', 'STS-V8', 'XLR-V8', 'AVEO', 'Cavalier',
#        'Classic', 'Cobalt', 'Corvette', 'Impala', 'Malibu', 'Monte Carlo',
#        'Bonneville', 'G6', 'Grand Am', 'Grand Prix', 'GTO', 'Sunfire',
#        'Vibe', '9_3', '9_3 HO', '9_5', '9_5 HO', '9-2X AWD', 'Ion',
#        'L Series'], dtype=object)

# %%
data["Model"].value_counts()
# Out:
# Cavalier       60
# Malibu         60
# AVEO           60
# Ion            50
# Cobalt         50
# 9_3 HO         40
# Vibe           30
# Bonneville     30
# Monte Carlo    30
# Deville        30
# Lacrosse       30
# Grand Prix     30
# Impala         30
# 9_5            30
# Park Avenue    20
# Lesabre        20
# Grand Am       20
# 9_3            20
# Corvette       20
# G6             20
# 9_5 HO         20
# GTO            10
# STS-V6         10
# CST-V          10
# Sunfire        10
# XLR-V8         10
# L Series       10
# Century        10
# STS-V8         10
# Classic        10
# CTS            10
# 9-2X AWD        4
# Name: Model, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data["Model"])
plt.xticks(rotation=270)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data
# Out:
#            Price  Mileage    Make     Model  ... Doors Cruise  Sound  Leather
# 0    17314.10313     8221   Buick   Century  ...     4      1      1        1
# 1    17542.03608     9135   Buick   Century  ...     4      1      1        0
# 2    16218.84786    13196   Buick   Century  ...     4      1      1        0
# 3    16336.91314    16342   Buick   Century  ...     4      1      0        0
# 4    16339.17032    19832   Buick   Century  ...     4      1      0        1
# ..           ...      ...     ...       ...  ...   ...    ...    ...      ...
# 799  16507.07027    16229  Saturn  L Series  ...     4      1      0        0
# 800  16175.95760    19095  Saturn  L Series  ...     4      1      1        0
# 801  15731.13290    20484  Saturn  L Series  ...     4      1      1        0
# 802  15118.89323    25979  Saturn  L Series  ...     4      1      1        0
# 803  13585.63680    35662  Saturn  L Series  ...     4      1      0        0
#
# [804 rows x 12 columns]

# %%
#Transformation
#MinMaxScaler operation

from sklearn.preprocessing import MinMaxScaler

dummy=['Make','Model','Type','Trim']
df_2=pd.get_dummies(data[dummy],drop_first=True)

# %%
#implementing the MinMaxScaler operation

scale=MinMaxScaler()

data["Mileage1"] = scale.fit_transform(data[["Mileage"]])

# %%
data.head()
# Out:
#          Price  Mileage   Make    Model  ... Cruise Sound  Leather  Mileage1
# 0  17314.10313     8221  Buick  Century  ...      1     1        1  0.158716
# 1  17542.03608     9135  Buick  Century  ...      1     1        0  0.176952
# 2  16218.84786    13196  Buick  Century  ...      1     1        0  0.257976
# 3  16336.91314    16342  Buick  Century  ...      1     0        0  0.320744
# 4  16339.17032    19832  Buick  Century  ...      1     0        1  0.390375
#
# [5 rows x 13 columns]

# %%
data.drop(data[dummy],axis=1,inplace=True)

# %%
data.head()
# Out:
#          Price  Mileage  Cylinder  Liter  ...  Cruise  Sound  Leather  Mileage1
# 0  17314.10313     8221         6    3.1  ...       1      1        1  0.158716
# 1  17542.03608     9135         6    3.1  ...       1      1        0  0.176952
# 2  16218.84786    13196         6    3.1  ...       1      1        0  0.257976
# 3  16336.91314    16342         6    3.1  ...       1      0        0  0.320744
# 4  16339.17032    19832         6    3.1  ...       1      0        1  0.390375
#
# [5 rows x 9 columns]

# %%
data.drop("Mileage",axis=1,inplace=True)

# %%
data
# Out:
#            Price  Cylinder  Liter  Doors  Cruise  Sound  Leather  Mileage1
# 0    17314.10313         6    3.1      4       1      1        1  0.158716
# 1    17542.03608         6    3.1      4       1      1        0  0.176952
# 2    16218.84786         6    3.1      4       1      1        0  0.257976
# 3    16336.91314         6    3.1      4       1      0        0  0.320744
# 4    16339.17032         6    3.1      4       1      0        1  0.390375
# ..           ...       ...    ...    ...     ...    ...      ...       ...
# 799  16507.07027         6    3.0      4       1      0        0  0.318489
# 800  16175.95760         6    3.0      4       1      1        0  0.375671
# 801  15731.13290         6    3.0      4       1      1        0  0.403384
# 802  15118.89323         6    3.0      4       1      1        0  0.513018
# 803  13585.63680         6    3.0      4       1      0        0  0.706211
#
# [804 rows x 8 columns]

# %%
data.head()
# Out:
#          Price  Cylinder  Liter  Doors  Cruise  Sound  Leather  Mileage1
# 0  17314.10313         6    3.1      4       1      1        1  0.158716
# 1  17542.03608         6    3.1      4       1      1        0  0.176952
# 2  16218.84786         6    3.1      4       1      1        0  0.257976
# 3  16336.91314         6    3.1      4       1      0        0  0.320744
# 4  16339.17032         6    3.1      4       1      0        1  0.390375

# %%
data_new= pd.concat([data,df_2], axis=1)

# %%
data_new.head()
# Out:
#          Price  Cylinder  ...  Trim_Special Ed Ultra 4D  Trim_Sportwagon 4D
# 0  17314.10313         6  ...                         0                   0
# 1  17542.03608         6  ...                         0                   0
# 2  16218.84786         6  ...                         0                   0
# 3  16336.91314         6  ...                         0                   0
# 4  16339.17032         6  ...                         0                   0
#
# [5 rows x 94 columns]

# %%
data_new.shape
# Out:
# (804, 94)

# %%
#implementing Linear regression byu just taking one dependent and one independent variable
# By taking Mileage1 as independent variable and predicting the price values

x=data_new[["Mileage1"]]
y=data_new[["Price"]]

# %%
#splitting the data into train and test

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_test.shape
# Out:
# (201, 1)

# %%
x_train.shape
# Out:
# (603, 1)

# %%
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()

lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predict=lr.predict(x_test)
predict
# Out:
# array([[19909.90658404],
#        [20101.08683569],
#        [19471.28497575],
#        [19785.379616  ],
#        [20137.1011099 ],
#        [21943.72761169],
#        [21739.10919802],
#        [23455.61042653],
#        [19532.74217005],
#        [20980.83850918],
#        [20796.1085753 ],
#        [18759.95826623],
#        [23808.04862241],
#        [19028.72150661],
#        [21478.40885486],
#        [20915.9769805 ],
#        [20984.78037004],
#        [19236.38590367],
#        [20180.46157935],
#        [18947.73418351],
#        [20096.42827286],
#        [21201.76189277],
#        [20714.04619924],
#        [20702.39979215],
#        [20346.5572619 ],
#        [20532.54142424],
#        [20273.27448503],
#        [22682.28899623],
#        [20362.14552984],
#        [20907.91408329],
#        [20327.0271331 ],
#        [20770.66565521],
#        [19590.79502997],
#        [20045.36325719],
#        [20586.6524233 ],
#        [23050.85298653],
#        [20160.93145055],
# ...

# %%
y_test
# Out:
#             Price
# 129  31059.181030
# 517  19204.809340
# 209   9220.829677
# 429  16295.211440
# 697  28054.982360
# ..            ...
# 753  14771.003460
# 633  32737.084550
# 513  22311.049510
# 617  15086.899590
# 756  13518.235250
#
# [201 rows x 1 columns]

# %%
#finding the error 

from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,predict)
# Out:
# 98999514.25294286

# %%
#This error can be reduced by giving more values for trainig and that type of regression is called Multiple Linear Regression
